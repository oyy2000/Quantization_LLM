# %% [markdown]
# <a href="https://colab.research.google.com/github/oyy2000/Quantization_LLM/blob/main/quantization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install autoawq
# !git clone https://github.com/oyy2000/Quantization_LLM.git
# Out:
# Collecting autoawq
#   Downloading autoawq-0.2.5-cp310-cp310-manylinux2014_x86_64.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.3/84.3 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: torch>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from autoawq) (2.2.1+cu121)
# Requirement already satisfied: transformers>=4.35.0 in /usr/local/lib/python3.10/dist-packages (from autoawq) (4.40.2)
# Requirement already satisfied: tokenizers>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from autoawq) (0.19.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from autoawq) (4.11.0)
# Collecting accelerate (from autoawq)
#   Downloading accelerate-0.30.1-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 21.4 MB/s eta 0:00:00
# Collecting datasets (from autoawq)
#   Downloading datasets-2.19.1-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 44.5 MB/s eta 0:00:00
# Collecting zstandard (from autoawq)
#   Downloading zstandard-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 85.3 MB/s eta 0:00:00
# Collecting autoawq-kernels (from autoawq)
#   Downloading autoawq_kernels-0.0.6-cp310-cp310-manylinux2014_x86_64.whl (33.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.4/33.4 MB 25.5 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.12.1->autoawq) (0.20.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (3.14.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=2.0.1->autoawq)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=2.0.1->autoawq)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=2.0.1->autoawq)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=2.0.1->autoawq)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=2.0.1->autoawq)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=2.0.1->autoawq)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=2.0.1->autoawq)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=2.0.1->autoawq)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=2.0.1->autoawq)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=2.0.1->autoawq)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=2.0.1->autoawq)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.0.1->autoawq)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35.0->autoawq) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35.0->autoawq) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35.0->autoawq) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35.0->autoawq) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35.0->autoawq) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35.0->autoawq) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35.0->autoawq) (4.66.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->autoawq) (5.9.5)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->autoawq)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 18.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (2.0.3)
# Collecting xxhash (from datasets->autoawq)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 28.2 MB/s eta 0:00:00
# Collecting multiprocess (from datasets->autoawq)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 20.8 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (3.9.5)
# Collecting huggingface-hub<1.0,>=0.16.4 (from tokenizers>=0.12.1->autoawq)
#   Downloading huggingface_hub-0.23.0-py3-none-any.whl (401 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 kB 48.0 MB/s eta 0:00:00
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.35.0->autoawq) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.35.0->autoawq) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.35.0->autoawq) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.35.0->autoawq) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.1->autoawq) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->autoawq) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->autoawq) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->autoawq) (2024.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.0.1->autoawq) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->autoawq) (1.16.0)
# Installing collected packages: zstandard, xxhash, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, dill, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, huggingface-hub, nvidia-cusolver-cu12, datasets, autoawq-kernels, accelerate, autoawq
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.20.3
#     Uninstalling huggingface-hub-0.20.3:
#       Successfully uninstalled huggingface-hub-0.20.3
# Successfully installed accelerate-0.30.1 autoawq-0.2.5 autoawq-kernels-0.0.6 datasets-2.19.1 dill-0.3.8 huggingface-hub-0.23.0 multiprocess-0.70.16 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 xxhash-3.4.1 zstandard-0.22.0
# Cloning into 'Quantization_LLM'...
# remote: Enumerating objects: 40, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 40 (delta 0), reused 34 (delta 0), pack-reused 0
# Receiving objects: 100% (40/40), 1.74 MiB | 6.13 MiB/s, done.

# %%
import os
import torch
import json
from transformers import AutoTokenizer
# from awq import AutoAWQForCausalLM
from generation import LLMGeneration
# Load environment variables

# import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "0, 1"

llm_gen = LLMGeneration(
    model_path="meta-llama/Llama-2-13b-chat-hf",   # TheBloke/Llama-2-7B-GPTQ, OriDragon2000/llama2-7b-gptq-w4-g128
    test_type="ethics",
    data_path="/eval_data",
    use_tuned_prompt=False,
)

llm_gen.generation_results()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 6
#       4 from transformers import AutoTokenizer
#       5 # from awq import AutoAWQForCausalLM
# ----> 6 from Quantization_LLM.generation import LLMGeneration
#       7 # Load environment variables
#       8
#       9 # import os
#      10 # os.environ["CUDA_VISIBLE_DEVICES"] = "0, 1"
#      12 llm_gen = LLMGeneration(
#      13     model_path="meta-llama/Llama-2-13b-chat-hf",   # TheBloke/Llama-2-7B-GPTQ, OriDragon2000/llama2-7b-gptq-w4-g128
#      14     test_type="ethics",
#      15     data_path="./Quantization_LLM/eval_data",
#      16     use_tuned_prompt=False,
#      17 )
#
# ModuleNotFoundError: No module named 'Quantization_LLM'

# %%
import os
import torch
import json
from transformers import AutoTokenizer
from generation import LLMGeneration
# Load environment variables

# import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "0, 1"

llm_gen = LLMGeneration(
    model_path="andrew-ye/Llama-2-13b-chat-hf-awq-4bit",   # TheBloke/Llama-2-7B-GPTQ, OriDragon2000/llama2-7b-gptq-w4-g128
    test_type="ethics",
    data_path="eval_data",
    use_tuned_prompt=True,
)

llm_gen.generation_results()
# Out:
# Beginning generation with ethics evaluation at temperature 0.
# Evaluation target model: llama2-13b-awq-w4
# /home/yo46/anaconda3/envs/trustllm/lib/python3.9/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Test function failed on attempt 1: local variable 'model' referenced before assignment
# Retrying in 3 seconds...
# Beginning generation with ethics evaluation at temperature 0.
# Evaluation target model: llama2-13b-awq-w4
# Test function failed on attempt 2: local variable 'model' referenced before assignment
# Retrying in 3 seconds...
# Beginning generation with ethics evaluation at temperature 0.
# Evaluation target model: llama2-13b-awq-w4
# Test function failed on attempt 3: local variable 'model' referenced before assignment
# Retrying in 3 seconds...
# Beginning generation with ethics evaluation at temperature 0.
# Evaluation target model: llama2-13b-awq-w4
# Test function failed on attempt 4: local variable 'model' referenced before assignment
# Retrying in 3 seconds...
# Beginning generation with ethics evaluation at temperature 0.
# Evaluation target model: llama2-13b-awq-w4
# Test function failed on attempt 5: local variable 'model' referenced before assignment
# Retrying in 3 seconds...
# Beginning generation with ethics evaluation at temperature 0.
# Evaluation target model: llama2-13b-awq-w4
# Test function failed on attempt 6: local variable 'model' referenced before assignment
# Retrying in 3 seconds...
# Beginning generation with ethics evaluation at temperature 0.
# Evaluation target model: llama2-13b-awq-w4
# Test function failed on attempt 7: local variable 'model' referenced before assignment
# Retrying in 3 seconds...
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# File ~/test/trustbenchmarks/Quantization_LLM/generation.py:348, in LLMGeneration.generation_results(self, max_retries, retry_interval)
#     347 try:
# --> 348     state = self._run_single_test()
#     349     if state:
#
# File ~/test/trustbenchmarks/Quantization_LLM/generation.py:326, in LLMGeneration._run_single_test(self)
#     325 if test_func:
# --> 326     test_func(model_name=model_name, model=model, tokenizer=tokenizer)
#     327     return "OK"
#
# UnboundLocalError: local variable 'model' referenced before assignment
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 18
#       6 # Load environment variables
#       7
#       8 # import os
#       9 # os.environ["CUDA_VISIBLE_DEVICES"] = "0, 1"
#      11 llm_gen = LLMGeneration(
#      12     model_path="andrew-ye/Llama-2-13b-chat-hf-awq-4bit",   # TheBloke/Llama-2-7B-GPTQ, OriDragon2000/llama2-7b-gptq-w4-g128
#      13     test_type="ethics",
#      14     data_path="eval_data",
#      15     use_tuned_prompt=True,
#      16 )
# ---> 18 llm_gen.generation_results()
#
# File ~/test/trustbenchmarks/Quantization_LLM/generation.py:355, in LLMGeneration.generation_results(self, max_retries, retry_interval)
#     353         print(f"Test function failed on attempt {attempt + 1}: {e}")
#     354         print(f"Retrying in {retry_interval} seconds...")
# --> 355         time.sleep(retry_interval)
#     357 print("Test failed after maximum retries.")
#     358 return None
#
# KeyboardInterrupt:

# %%
from google.colab import files
files.download('./generation_results/ethics/prompt_tuned/implicit_ETHICS.json')

# %%
from google.colab import files
files.download('./generation_results/ethics/prompt_tuned/implicit_ETHICS.json')

# %%
import os
import torch
import json
from transformers import AutoTokenizer
from awq import AutoAWQForCausalLM
from Quantization_LLM.generation import LLMGeneration
# Load environment variables

# import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "0, 1"

llm_gen = LLMGeneration(
    model_path="andrew-ye/Llama-2-13b-chat-hf-awq-4bit",   # TheBloke/Llama-2-7B-GPTQ, OriDragon2000/llama2-7b-gptq-w4-g128
    test_type="truthfulness",
    data_path="./Quantization_LLM/eval_data",
    use_tuned_prompt=True,
)

llm_gen.generation_results()
# Out:
# Beginning generation with truthfulness evaluation at temperature 0.
# Evaluation target model:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Fetching 10 files:   0%|          | 0/10 [00:00<?, ?it/s]
# Replacing layers...: 100%|██████████| 40/40 [00:11<00:00,  3.54it/s]
# Fusing layers...: 100%|██████████| 40/40 [00:01<00:00, 24.86it/s]
# Processing files:   0%|          | 0/6 [00:00<?, ?it/s]
# hallucination.json not in file_config
# test_res not in file_config
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:   0%|          | 0/419 [00:00<?, ?it/s]
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:   3%|▎         | 12/419 [00:00<00:03, 112.13it/s]
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:   6%|▌         | 24/419 [00:00<00:03, 110.50it/s]
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:   9%|▊         | 36/419 [00:00<00:03, 107.67it/s]
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  11%|█▏        | 48/419 [00:00<00:03, 109.52it/s]
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  14%|█▍        | 60/419 [00:00<00:03, 110.69it/s]
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  17%|█▋        | 72/419 [00:00<00:03, 110.99it/s]
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  20%|██        | 84/419 [00:00<00:03, 109.92it/s]
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  23%|██▎       | 95/419 [00:00<00:02, 109.87it/s]
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  25%|██▌       | 106/419 [00:00<00:02, 109.83it/s]
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  28%|██▊       | 117/419 [00:01<00:02, 109.57it/s]
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  31%|███       | 129/419 [00:01<00:02, 109.85it/s]
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  33%|███▎      | 140/419 [00:01<00:02, 109.83it/s]
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  36%|███▋      | 152/419 [00:01<00:02, 110.27it/s]
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  39%|███▉      | 164/419 [00:01<00:02, 110.17it/s]
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  42%|████▏     | 176/419 [00:01<00:02, 110.24it/s]
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  45%|████▍     | 188/419 [00:01<00:02, 109.51it/s]
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  47%|████▋     | 199/419 [00:01<00:02, 109.46it/s]
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  50%|█████     | 211/419 [00:01<00:01, 109.70it/s]
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  53%|█████▎    | 222/419 [00:02<00:01, 109.57it/s]
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  56%|█████▌    | 233/419 [00:02<00:01, 109.51it/s]
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  58%|█████▊    | 245/419 [00:02<00:01, 109.98it/s]
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  61%|██████    | 256/419 [00:02<00:01, 109.57it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  61%|██████    | 256/419 [00:15<00:01, 109.57it/s]
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  63%|██████▎   | 264/419 [00:15<01:00,  2.55it/s] Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:
24s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  93%|█████████▎| 388/419 [18:37<03:32,  6.85s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  93%|█████████▎| 389/419 [18:48<03:59,  7.99s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  93%|█████████▎| 390/419 [18:56<03:54,  8.10s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  93%|█████████▎| 391/419 [19:01<03:18,  7.09s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  94%|█████████▎| 392/419 [19:09<03:19,  7.40s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  94%|█████████▍| 393/419 [19:20<03:40,  8.48s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  94%|█████████▍| 394/419 [19:34<04:10, 10.01s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  94%|█████████▍| 395/419 [19:44<04:02, 10.11s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  95%|█████████▍| 396/419 [19:50<03:26,  8.98s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  95%|█████████▍| 397/419 [19:59<03:15,  8.88s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  95%|█████████▍| 398/419 [20:11<03:27,  9.89s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  95%|█████████▌| 399/419 [20:24<03:35, 10.79s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  95%|█████████▌| 400/419 [20:38<03:41, 11.68s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  96%|█████████▌| 401/419 [20:44<02:59, 10.00s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  96%|█████████▌| 402/419 [20:50<02:30,  8.84s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  96%|█████████▌| 403/419 [21:04<02:45, 10.34s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  96%|█████████▋| 404/419 [21:13<02:27,  9.80s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  97%|█████████▋| 405/419 [21:22<02:17,  9.82s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  97%|█████████▋| 406/419 [21:34<02:15, 10.42s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  97%|█████████▋| 407/419 [21:44<02:02, 10.24s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  97%|█████████▋| 408/419 [21:50<01:39,  9.06s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  98%|█████████▊| 409/419 [21:56<01:20,  8.04s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  98%|█████████▊| 410/419 [22:04<01:12,  8.04s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  98%|█████████▊| 411/419 [22:13<01:06,  8.36s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  98%|█████████▊| 412/419 [22:22<01:00,  8.59s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  99%|█████████▊| 413/419 [22:32<00:53,  8.88s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  99%|█████████▉| 414/419 [22:39<00:42,  8.47s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  99%|█████████▉| 415/419 [22:51<00:37,  9.39s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json:  99%|█████████▉| 416/419 [23:02<00:29,  9.82s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json: 100%|█████████▉| 417/419 [23:08<00:17,  8.83s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json: 100%|█████████▉| 418/419 [23:17<00:08,  8.90s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#
# Processing ./Quantization_LLM/eval_data/truthfulness/sycophancy.json: 100%|██████████| 419/419 [23:24<00:00,  8.25s/it]
# Processing files: 100%|██████████| 6/6 [23:24<00:00, 234.09s/it]
# golden_advfactuality.json not in file_config
# internal.json not in file_config
# external.json not in file_config
# Test function successful on attempt 1
# 'OK'

# %%
from google.colab import files
files.download('./generation_results/truthfulness/prompt_tuned/sycophancy.json')

# %%
# Out:
# Cloning into 'Quantization_LLM'...
# remote: Enumerating objects: 40, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 40 (delta 0), reused 34 (delta 0), pack-reused 0
# Receiving objects: 100% (40/40), 1.74 MiB | 15.94 MiB/s, done.

# %%
# !pip install auto-gptq
# !pip install optimum
# !pip install torch==2.1.0 torchvision==0.16.0 torchaudio==2.1.0 --index-url https://download.pytorch.org/whl/cu121

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, GPTQConfig
import torch
import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "1,2"

model_id = "meta-llama/Llama-2-7b-chat-hf"

quantization_config = GPTQConfig(
     bits=4,
     group_size=128,
     dataset="c4",
     desc_act=False,
)

tokenizer = AutoTokenizer.from_pretrained(model_id)
quant_model = AutoModelForCausalLM.from_pretrained(model_id, quantization_config=quantization_config, device_map='auto')

# Set up the directory where you want to save the model
save_directory = "llama2-7b-gptq-w4-g128"

# Save the quantized model

quant_model.push_to_hub(save_directory)
tokenizer.push_to_hub(save_directory)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda:CUDA extension not installed.
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda_old:CUDA extension not installed.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/41.1k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/319M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Quantizing model.layers blocks :   0%|          | 0/32 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:4371: FutureWarning: `_is_quantized_training_enabled` is going to be deprecated in transformers 4.39.0. Please use `model.hf_quantizer.is_trainable` instead
#   warnings.warn(
# The cos_cached attribute will be removed in 4.39. Bear in mind that its contents changed in v4.38. Use the forward method of RoPE from now on instead. It is not used in the `LlamaAttention` class
# The sin_cached attribute will be removed in 4.39. Bear in mind that its contents changed in v4.38. Use the forward method of RoPE from now on instead. It is not used in the `LlamaAttention` class
# README.md:   0%|          | 0.00/5.17k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.90G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/OriDragon2000/llama2-7b-gptq-w4-g128/commit/15611d070594dc5ecdaf1b4f32efb27478631568', commit_message='Upload tokenizer', commit_description='', oid='15611d070594dc5ecdaf1b4f32efb27478631568', pr_url=None, pr_revision=None, pr_num=None)

# %%
from huggingface_hub import notebook_login
notebook_login()
# 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
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !nvidia-smi
# Out:
# Fri May 10 15:00:04 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0              40W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
†quant_model.push_to_hub(save_directory)
tokenizer.push_to_hub(save_directory)
